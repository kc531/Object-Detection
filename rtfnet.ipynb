# %% [markdown]
# <a href="https://colab.research.google.com/github/kc531/Object-Detection/blob/main/rtfnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/RTFNet-master
# Out:
# /content/drive/MyDrive/RTFNet-master

# %%
# !pip install setuptools>=40.3.0 
# !pip3 install -U scipy scikit-learn
# !pip3 install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install torchsummary
# !pip3 install tensorboard==2.2.0
# Out:
# ...
#      |████████████████████████████████| 12.9MB 51.5MB/s
# ...
#      |████████████████████████████████| 7.6MB 10.2MB/s
# ...
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.7.1+cu110 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/segmentation/tensorboard_log/

# %%
# !python train.py -em 50
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: RTFNet, epo 41/50, iter 76/784, lr 0.00122087, 2.71 img/sec, loss 0.0224, time 8:07:10
# Train: RTFNet, epo 41/50, iter 77/784, lr 0.00122087, 2.70 img/sec, loss 0.0212, time 8:07:10
# Train: RTFNet, epo 41/50, iter 78/784, lr 0.00122087, 2.70 img/sec, loss 0.0109, time 8:07:11
# Train: RTFNet, epo 41/50, iter 79/784, lr 0.00122087, 2.70 img/sec, loss 0.0192, time 8:07:12
# Train: RTFNet, epo 41/50, iter 80/784, lr 0.00122087, 2.71 img/sec, loss 0.0329, time 8:07:12
# Train: RTFNet, epo 41/50, iter 81/784, lr 0.00122087, 2.70 img/sec, loss 0.0304, time 8:07:13
# Train: RTFNet, epo 41/50, iter 82/784, lr 0.00122087, 2.70 img/sec, loss 0.0170, time 8:07:14
# Train: RTFNet, epo 41/50, iter 83/784, lr 0.00122087, 2.71 img/sec, loss 0.0142, time 8:07:15
# Train: RTFNet, epo 41/50, iter 84/784, lr 0.00122087, 2.70 img/sec, loss 0.0240, time 8:07:16
# ...

# %%
# %cd /content
# %mkdir weights
# %cd /content/weights
# %mkdir RTFNet
# %mkdir results

# %%
# %cd /content/drive/MyDrive/RTFNet-master
# !python run_demo.py
